# %% [markdown]
# # Netflix Dataset from Kaggle
#
# ## Big Data Analysis with Python
#
# This Netflix Dataset has information about the TV Shows and Movies available on netflix till 2021.
#
# #### by: Arie Yudistira

# %%
# Importing the dataset
import pandas as pd
data = pd.read_csv(r"C:\Users\user\Documents\MyProject\Dataset\netflix_titles.csv") # to import pandas library

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### Getting some basic information about the dataset

# %% [markdown]
# #### 1. Show top 5 records of the dataset

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# #### 2. Show bottom 5 records of the dataset

# %%
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# #### 3. Show the No. of rows and columns

# %%
data.shape
# Out:
# (8807, 12)

# %% [markdown]
# #### 4. Show No. of total values(elements)

# %%
data.size
# Out:
# 105684

# %% [markdown]
# #### 5. Show each column name

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# #### 6. Show the data type of each column

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# #### 7. Show indexes, column, data types of each column, memory at once

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# #### Task. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data[data.duplicated()]    # to check row wise and detect the Duplicate rows
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# ##### Note: No duplicate data
# if there is data duplicate use the command = data.drop_duplicates(inplace = True) #to Remove the duplicate rows permanently,
# if you still need the data and not permanent remove use the command = data.drop_duplicates()

# %% [markdown]
# #### Task. 2) Is there any Null Value present in any column ? Show with Heat-map.

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
 data.isnull()   # to show where Null value is present
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()   # to show the count of Null values in each column
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# #### seaborn library (heat-map)

# %%
import seaborn as sns    # to import Seaborn library

# %%
sns.heatmap(data.isnull())    # using heat-map to show null values count
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Q. 1) For '13 Reasons Why', what is the Show Id and Who is the Director of this show ?

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data[data['title'].isin(['13 Reasons Why'])]    # to show all records of a particular item in any column
# Out:
#      show_id     type           title director  \
# 2417   s2418  TV Show  13 Reasons Why      NaN
#
#                                                    cast        country  \
# 2417  Dylan Minnette, Katherine Langford, Kate Walsh...  United States
#
#         date_added  release_year rating   duration  \
# 2417  June 5, 2020          2020  TV-MA  4 Seasons
#
#                                     listed_in  \
# 2417  Crime TV Shows, TV Dramas, TV Mysteries
#
#                                             description
# 2417  After a teenage girl's perplexing suicide, a c...

# %%
data[data['title'].str.contains('13 Reasons Why')]    # to show all records of a particular string in any column
# Out:
#      show_id     type                               title director  \
# 2417   s2418  TV Show                      13 Reasons Why      NaN
# 3561   s3562  TV Show  13 Reasons Why: Beyond the Reasons      NaN
#
#                                                    cast        country  \
# 2417  Dylan Minnette, Katherine Langford, Kate Walsh...  United States
# 3561  Dylan Minnette, Katherine Langford, Kate Walsh...  United States
#
#            date_added  release_year rating   duration  \
# 2417     June 5, 2020          2020  TV-MA  4 Seasons
# 3561  August 23, 2019          2019  TV-MA  3 Seasons
#
#                                     listed_in  \
# 2417  Crime TV Shows, TV Dramas, TV Mysteries
# 3561               Crime TV Shows, Docuseries
#
#                                             description
# 2417  After a teenage girl's perplexing suicide, a c...
# 3561  Cast members, writers, producers and mental he...

# %% [markdown]
# #### Q. 2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data['Date_N'] = pd.to_datetime(data['date_added'])

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data['Date_N'].dt.year.value_counts()   # it counts the accurence of all individual Years in date column
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')    # to show Bar Graph
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Q. 3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24

# %%
data.groupby('type').type.count()    # to group all unique items of a column and show their count
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(data['type'])    # to show the count of all unique values of any column in the form of bar graph
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# #### Q. 4) Show all the Movies that were added in year 2010.

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24

# %%
data['Year'] = data['Date_N'].dt.year    # to create new Year column ; it will consider only year

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data[(data['type'] == 'Movie') & (data['Year'] == 2010)]    # Filtering
# Out:
#      show_id   type                        title    director  \
# 7370   s7371  Movie  Mad Ron's Prevues from Hell  Jim Monaco
#
#                                                    cast        country  \
# 7370  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States
#
#             date_added  release_year rating duration  \
# 7370  November 1, 2010          1987     NR   84 min
#
#                        listed_in  \
# 7370  Cult Movies, Horror Movies
#
#                                             description     Date_N    Year
# 7370  This collection cherry-picks trailers, forgott... 2010-11-01  2010.0

# %% [markdown]
# #### Q. 5) Show only the Titles of all TV Shows that were released in Indonesia only.

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
# show all tv shows that were released in indonesia
data[(data['type']=='TV Show') & (data['country']=='Indonesia')]
# Out:
#      show_id     type                                        title director  \
# 1605   s1606  TV Show  Check The Store Next Door: The Next Chapter      NaN
# 6937   s6938  TV Show                               Hati Perempuan      NaN
#
#                                                    cast    country  \
# 1605  Ernest Prakasa, Chew Kin Wah, Dion Wiyoko, Mor...  Indonesia
# 6937  Saharul Ridzwan, Mia Ahmad, Hafreez Adam, Hafe...  Indonesia
#
#             date_added  release_year rating   duration  \
# 1605  December 2, 2020          2020  TV-14  2 Seasons
# 6937   August 21, 2017          2015  TV-14   1 Season
#
#                                               listed_in  \
# 1605     International TV Shows, TV Comedies, TV Dramas
# 6937  International TV Shows, Romantic TV Shows, TV ...
#
#                                             description     Date_N    Year
# 1605  When a former shop owner grows bored of retire... 2020-12-02  2020.0
# ...

# %%
# show only the titles of all tv shows that were released in indonesia
data[(data['type']=='TV Show') & (data['country']=='Indonesia')] ['title']
# Out:
# 1605    Check The Store Next Door: The Next Chapter
# 6937                                 Hati Perempuan
# Name: title, dtype: object

# %% [markdown]
# #### Q. 6) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# #### Q. 7) Show all the Records, where "Category is Movie and Genre is Horror Movies" or "Country is Canada".

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data[(data['type']=='Movie') & (data['listed_in']=='Horror Movies')]
# Out:
#      show_id   type                                             title  \
# 229     s230  Movie                                      The Old Ways
# 307     s308  Movie                                         Aftermath
# 353     s354  Movie  The Haunting in Connecticut 2: Ghosts of Georgia
# 479     s480  Movie                          Fear Street Part 2: 1978
# 586     s587  Movie                                    Pet Sematary 2
# 643     s644  Movie                                   The Seventh Day
# 728     s729  Movie                                   The Devil Below
# 822     s823  Movie                                          The Wind
# 962     s963  Movie                      The Strangers: Prey at Night
# 1284   s1285  Movie                                   The Conjuring 2
# 1297   s1298  Movie                                    No Escape Room
# 1367   s1368  Movie                                         Hell Fest
# ...

# %%
data[(data['type']=='Movie') & (data['listed_in']=='Horror Movies') | (data['country']=='Canada')]
# Out:
#      show_id   type                                             title  \
# 157     s158  Movie                                          Level 16
# 229     s230  Movie                                      The Old Ways
# 307     s308  Movie                                         Aftermath
# 353     s354  Movie  The Haunting in Connecticut 2: Ghosts of Georgia
# 479     s480  Movie                          Fear Street Part 2: 1978
# ...      ...    ...                                               ...
# 8642   s8643  Movie                                              Tusk
# 8649   s8650  Movie                             Two Lovers and a Bear
# 8659   s8660  Movie                                Undercover Grandpa
# 8753   s8754  Movie                                         Withdrawn
# 8765   s8766  Movie                                                XX
#
#                                                director  \
# 157                                  Danishka Esterhazy
# ...

# %% [markdown]
# #### Q. 8) In how many movies/shows, Robert Downey Jr. was cast ?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data[data['cast'] == 'Robert Downey Jr.']    # Filtering
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N, Year]
# Index: []

# %%
data[data['cast'].str.contains('Robert Downey Jr.')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [88], in <cell line: 1>()
# ----> 1 data[data['cast'].str.contains('Robert Downey Jr.')]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3495, in DataFrame.__getitem__(self, key)
#    3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
# -> 3495 if com.is_bool_indexer(key):
#    3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
#    3499 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\common.py:144, in is_bool_indexer(key)
#     140     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     141     if lib.infer_dtype(key) == "boolean" and isna(key).any():
# ...

# %%
# Creating new data-frame
data_new = data.dropna() # it drops the rows that contains all or any missing values

# %%
data_new.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description     Date_N    Year
# ...

# %%
data_new[data_new['cast'].str.contains('Robert Downey Jr.')]
# Out:
#      show_id   type                      title                  director  \
# 930     s931  Movie                   Due Date             Todd Phillips
# 1612   s1613  Movie                       Chef               Jon Favreau
# 6200   s6201  Movie     Avengers: Infinity War  Anthony Russo, Joe Russo
# 6878   s6879  Movie  Good Night, and Good Luck            George Clooney
# 6886   s6887  Movie                    Gothika         Mathieu Kassovitz
# 8003   s8004  Movie            Sherlock Holmes               Guy Ritchie
# 8802   s8803  Movie                     Zodiac             David Fincher
#
#                                                    cast  \
# 930   Robert Downey Jr., Zach Galifianakis, Michelle...
# 1612  Jon Favreau, Sofía Vergara, John Leguizamo, Sc...
# 6200  Robert Downey Jr., Josh Brolin, Mark Ruffalo, ...
# 6878  David Strathairn, Patricia Clarkson, George Cl...
# 6886  Halle Berry, Robert Downey Jr., Charles S. Dut...
# ...

# %% [markdown]
# #### Q. 9) What are the different Ratings defined by Netflix ?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data['rating'].nunique()
# Out:
# 17

# %%
data['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# #### Q. 9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data[(data['type']=='Movie') & (data['rating']=='TV-14')].shape
# Out:
# (1427, 14)

# %%
data[(data['type']=='Movie') & (data['rating']=='TV-14') & (data['country']=='Canada')]
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 1279   s1280  Movie   Made You Look: A True Story About Fake Art
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5972   s5973  Movie                             #cats_the_mewvie
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8178   s8179  Movie                  The Accountant of Auschwitz
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# ...

# %% [markdown]
# #### Q. 9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data[(data['type']=='TV Show') & (data['rating']=='R')]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
# 7593   s7594  TV Show                                Nobel                NaN
#
#                                                    cast country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
#
#              date_added  release_year rating  duration  \
# 3893     April 25, 2019          2015      R  1 Season
# 7593  December 10, 2016          2016      R  1 Season
#
#                                             listed_in  \
# 3893                                         TV Shows
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description     Date_N    Year
# 3893  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0
# ...

# %%
data[(data['type']=='TV Show') & (data['rating']=='R') & (data['Year'] > 2018)]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#           date_added  release_year rating  duration listed_in  \
# 3893  April 25, 2019          2015      R  1 Season  TV Shows
#
#                                             description     Date_N    Year
# 3893  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# #### Q. 10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
data.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
data.duration.dtypes
# Out:
# dtype('O')

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#   Minutes     Unit
# ...

# %%
data[['Minutes','Unit']] = data['duration'].str.split(' ', expand = True)

# %%
data.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
import pandas as pd

data['Minutes'] = pd.to_numeric(data['Minutes'])

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# Year                   float64
# Minutes                float64
# Unit                    object
# dtype: object

# %%
data['Minutes'].max()
# Out:
# 312.0

# %%
data['Minutes'].min()
# Out:
# 1.0

# %%
data['Minutes'].mean()
# Out:
# 69.84688777828259

# %% [markdown]
# #### Q. 11) Which individual country has the Highest No. of TV Shows ?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#    Minutes     Unit
# ...

# %%
data_tvshow = data[data['type'] == 'TV Show']

# %%
data_tvshow.head(2)
# Out:
#   show_id     type          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description     Date_N    Year  \
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
# 2  To protect his family from a powerful drug lor... 2021-09-24  2021.0
#
#    Minutes     Unit
# 1      2.0  Seasons
# ...

# %%
data_tvshow.country.value_counts()
# Out:
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: country, Length: 196, dtype: int64

# %%
data_tvshow.country.value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64

# %% [markdown]
# #### Q. 12) How can we sort the dataset by Year ?

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#    Minutes     Unit
# ...

# %%
data.sort_values(by='Year')
# Out:
#      show_id     type                         title              director  \
# 5957   s5958    Movie          To and From New York  Sorin Dan Mihalcescu
# 6611   s6612  TV Show               Dinner for Five                   NaN
# 5956   s5957    Movie       Just Another Love Story          Ole Bornedal
# 5955   s5956    Movie                      Splatter             Joe Dante
# 7370   s7371    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 7196   s7197  TV Show                      Kikoriki                   NaN
# 7254   s7255  TV Show           La Familia P. Luche                   NaN
# 7406   s7407  TV Show                         Maron                   NaN
# 7847   s7848  TV Show                  Red vs. Blue                   NaN
# 8182   s8183  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    cast        country  \
# ...

# %%
data.sort_values(by = 'Year', ascending = False).head(10)
# Out:
#      show_id     type                               title         director  \
# 0         s1    Movie                Dick Johnson Is Dead  Kirsten Johnson
# 996     s997    Movie                          HOMUNCULUS  Takashi Shimizu
# 1005   s1006    Movie  Keymon and Nani in Space Adventure              NaN
# 1004   s1005  TV Show                  Izzy's Koala World              NaN
# 1003   s1004  TV Show                                Zero              NaN
# 1002   s1003    Movie                        Tell Me When   Gerardo Gatica
# 1001   s1002    Movie                            Oloibiri    Curtis Graham
# 1000   s1001    Movie                            Wild Dog  Ahishor Solomon
# 999    s1000    Movie                            Stowaway        Joe Penna
# 998     s999    Movie                Searching For Sheela              NaN
#
#                                                    cast  \
# 0                                                   NaN
# ...

# %% [markdown]
# #### Q. 13) Find all the instances where: Category is 'Movie' and Genre is 'Horror Movies' or Category is 'TV Show' & Genre is 'Kids' TV'.

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N    Year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
#    Minutes     Unit
# ...

# %%
data[(data['type']=='Movie') & (data['listed_in']=='Horror Movies')].head(2)
# Out:
#     show_id   type         title             director  \
# 229    s230  Movie  The Old Ways  Christopher Alender
# 307    s308  Movie     Aftermath        Peter Winther
#
#                                                   cast        country  \
# 229  Brigitte Kali Canales, Andrea Cortes, Julia Ve...  United States
# 307  Ashley Greene, Shawn Ashmore, Sharif Atkins, B...  United States
#
#           date_added  release_year rating duration      listed_in  \
# 229  August 25, 2021          2020  TV-MA   90 min  Horror Movies
# 307   August 4, 2021          2021  TV-MA  115 min  Horror Movies
#
#                                            description     Date_N    Year  \
# 229  A reporter visits her birthplace in Veracruz f... 2021-08-25  2021.0
# 307  Desperate to save their marriage, a young coup... 2021-08-04  2021.0
#
#      Minutes Unit
# 229     90.0  min
# 307    115.0  min

# %%
data[(data['type']=='TV Show') & (data['listed_in']=="Kids' TV")].head(2)
# Out:
#    show_id     type                    title director  \
# 34     s35  TV Show  Tayo and Little Wizards      NaN
# 39     s40  TV Show             Chhota Bheem      NaN
#
#                                                  cast country  \
# 34  Dami Lee, Jason Lee, Bommie Catherine Han, Jen...     NaN
# 39  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
#
#             date_added  release_year rating   duration listed_in  \
# 34  September 17, 2021          2020  TV-Y7   1 Season  Kids' TV
# 39  September 16, 2021          2021  TV-Y7  3 Seasons  Kids' TV
#
#                                           description     Date_N    Year  \
# 34  Tayo speeds into an adventure when his friends... 2021-09-17  2021.0
# 39  A brave, energetic little boy with superhuman ... 2021-09-16  2021.0
#
#     Minutes     Unit
# 34      1.0   Season
# 39      3.0  Seasons

# %%
data[(data['type']=='Movie') & (data['listed_in']=='Horror Movies') | (data['type']=='TV Show') & (data['listed_in']=="Kids' TV")]
# Out:
#      show_id     type                    title  \
# 34       s35  TV Show  Tayo and Little Wizards
# 39       s40  TV Show             Chhota Bheem
# 65       s66  TV Show             Numberblocks
# 89       s90  TV Show              Mighty Raju
# 100     s101  TV Show  Tobot Galaxy Detectives
# ...      ...      ...                      ...
# 8679   s8680  TV Show       ViR: The Robot Boy
# 8765   s8766    Movie                       XX
# 8783   s8784  TV Show                     Yoko
# 8785   s8786  TV Show                      YOM
# 8797   s8798  TV Show                Zak Storm
#
#                                                director  \
# 34                                                  NaN
# 39                                                  NaN
# 65                                                  NaN
# 89                                                  NaN
# 100                                                 NaN
# ...

# %% [markdown]
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# #### By: Arie Yudistira (Data Analyst)
